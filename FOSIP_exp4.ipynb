# %% [markdown]
# <a href="https://colab.research.google.com/github/KomalT2003/SignalProcessing/blob/main/FOSIP_exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install matplotlib


import numpy as np
import matplotlib.pyplot as plt
import time

def calculate_fft(signal):
    N = len(signal)
    if N <= 1:
        return signal

    even = calculate_fft(signal[0::2])
    odd = calculate_fft(signal[1::2])

    T = [np.exp(-2j * np.pi * k / N) * odd[k] for k in range(N // 2)]

    return [even[k] + T[k] for k in range(N // 2)] + [even[k] - T[k] for k in range(N // 2)]

signal = [1, 2, 3, 4,5,6,7,8]
print("Original Signal: ", signal)
fftSignal = calculate_fft(signal)
print("FFT Signal: ", fftSignal)


# Plot the FFT result
plt.figure(figsize=(10, 4))
plt.subplot(121)
plt.title("Original Signal")
plt.stem(signal)

plt.subplot(122)
plt.title("FFT Result")
plt.stem(np.abs(fftSignal))
plt.show()
# Out:
# ...
# Original Signal:  [1, 2, 3, 4, 5, 6, 7, 8]
# FFT Signal:  [(36+0j), (-4+9.65685424949238j), (-4+4j), (-4+1.6568542494923797j), (-4+0j), (-3.9999999999999996-1.6568542494923797j), (-3.9999999999999996-4j), (-3.9999999999999987-9.65685424949238j)]
